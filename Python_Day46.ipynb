# %% [markdown]
# # Important Instructions

# %% [markdown]
# ###### I hope you enjoyed Python classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### a) Using the above diagram create a class which has two students objects and print the output has shown below, where students belong to institute  “Rooman Technologies”
#
# Hint: Use static variable
#
# Sample Output:
#
# Hi  Raj  Welcome to  Rooman Technologies Online Training
#
# Raj Enrolled to course
#
# Opted subject: Java
#
# Secured A Grade
#
# Hi  Ram  Welcome to  Rooman Technologies Online Training
#
# Ram Enrolled to course
#
# Opted subject: Python
#
# Secured B Grade
