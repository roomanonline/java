# %% [markdown]
# # Important Instructions

# %% [markdown]
# ###### I hope you enjoyed Python classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 1)Here is a Food_Factory which produces the following items, where in each productions there is a particular name of product and number of productions made as shown below.
#
# Write a script for the above scenario.
#
# Hint: Use @classmethod decorator
#
# Sample Output:
#
# Product_Name: Sweets   No_of_Production: 1000
#
# Product_Name: Shortbread Cookies   No_of_Production: 2000
#
# Product_Name: Popcorn cerals   No_of_Production: 502

# %% [markdown]
# ###### 2)Below, is the list of discounts available for certain products in online shopping. Write a script which calculates the discount of product and display the output:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Hint: Use @staticmethod
#
# ###### Sample Output:
#
# Men's footwear
#
# Original_price 5000 Rs
#
# Discount Price: 3750.0 Rs
#
# Accessories
#
# Original_price 600 Rs
#
# Discount Price: 300.0 Rs
