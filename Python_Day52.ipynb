# %% [markdown]
# # Important Instructions

# %% [markdown]
# ###### I hope you enjoyed Python classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

# %% [markdown]
# 1) ![image.png](attachment:image.png)

# %% [markdown]
# ###### Here, is a parent class Android with one function versions() and two subclasses Jelly Bean and KitKat which inherits from parent. Override the function present in parent class Android in both the subclasses such that the output is as shown below.
#
# <b>Sample Output:</b>
#
# Android Jelly Bean version 4.1 - 4.3.1
#
# Android KitKat version 4.4 - 4.4.4

# %% [markdown]
# 2) ![image.png](attachment:image.png)

# %% [markdown]
# ###### Write a script for above scenario and print the “Method Resolution Oder"

# %% [markdown]
# 3) ![image.png](attachment:image.png)

# %% [markdown]
# ###### Write a script for above diagram and print the output as shown below.
#
# <b>Sample Output:</b>
#
# Python Idle comes with simple text formatting
#
# debugs code in idle
#
# JupyterNotebook comes with rich text formatting
#
# debugs code in JupyterNotebook
#
# JupyterNotebook consist of autosaving option
