# %% [markdown]
# # Important Instructions

# %% [markdown]
# ###### I hope you enjoyed Python classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### a) Using the above diagram create a class which has two objects and print the output has shown below.
#
# Hi Raj Welcome to Online Training
#
# Raj Enrolled to course
#
# Opted subject: Java
#
# Secured A Grade
#
# Hi Ram Welcome to Online Training
#
# Ram Enrolled to course
#
# Opted subject: Python
#
# Secured B Grade

# %% [markdown]
# ###### b) Using the above scenario set the enrollment number of students and print the output.
#
# <b>Hint : Use setattr() and getattr()</b>
#
# Enrollment Number:
#
# Raj 00101
#
# Ram 00102
#
# <b>Sample Output:</b>
#
# Hi  Raj  Welcome to Online Training
#
# Raj Enrolled to course
#
# Opted subject: Java
#
# Secured A Grade
#
# Hi  Ram  Welcome to Online Training
#
# Ram Enrolled to course
#
# Opted subject: Python
#
# Secured B Grade
#
# Raj Enrollment No: 00101
#
# Ram Enrollment No: 00102
