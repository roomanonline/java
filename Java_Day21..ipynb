// %% [markdown]
// # Important Instructions:

// %% [raw]
// 1)When coding in java using jupyter notebooks there is no need to provide a main method as it is automatically provided.
//
// 2)Code written within a cell is automatically placed within the main method unless you explicitly place it within another class
//
// I hope you enjoyed the classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

// %% [raw]
// Write a  Employee class, which has three overloaded constructors with different number of signatures. When we create  different objects with different parameters, then respective matching constructor get called.
// Sample output :
// Employee Info:
// ID: 0
// Name: Not Available
// Employee Info:
// ID: 123
// Name: Not Available
// Employee Info:
// ID: 124
// Name: Vicky

// %% [raw]
// Write a program compare the price of two cars in highestPriceCar(Car c) method. In if condition, to distinguish the incoming car object in parameter and with current car object we have refer the getPrice() method using this keyword.
