// %% [markdown]
// # Important Instructions:

// %% [raw]
// 1)When coding in java using jupyter notebooks there is no need to provide a main method as it is automatically provided.
//
// 2)Code written within a cell is automatically placed within the main method unless you explicitly place it within another class
//
// I hope you enjoyed the classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

// %% [raw]
// /*Complete the code segment to catch the ArithmeticException, if any. On the occurrence of such an exception, your program should print “Exception caught: Division by zero.” If there is no such exception, it will print the result of division operation on two integer values.
//
// import java.util.Scanner;
// public class ArithExcep {
// 	public static void main(String[] args) {
// 		int numerator, denominator;
// 		Scanner input = new Scanner(System.in);
//
// 		System.out.println("Enter Numerator : ");
// //Read any two values for numerator and denominator.
//
// 		System.out.println("Enter Denominator : ");
//
// //Get the result of a/b;
// 		try {
//
//
// 		    }
//         catch (ArithmeticException e) {
// 			System.out.print("Exception caught: Division by zero");
// 		}
//      }
//
// Sample input and output 1:
//
// Enter Numerator : 12
// Enter Denominator : 3
// Quotient : 4
//
// Sample input and output 2:
//
// Enter Numerator : 34
// Enter Denominator : 0
// Exception caught: Division by zero

// %% [raw]
// /*Handle exception in number Problem statement: Get the input String from user and parse it to integer, if it is not a number it will throw number format exception Catch it and print "Entered input is not a valid format for an integer." or else print the square of that number
//
// Sample input and output 1:
//
// Enter an integer: 12
//  The square value is 144
//  The work has been done successfully
//
// Sample input and output 2:
//
// Enter an integer: Java
// Entered input is not a valid format for an integer.
//  */
