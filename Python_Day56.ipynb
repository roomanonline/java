# %% [markdown]
# # Important Instructions

# %% [markdown]
# ###### I hope you enjoyed Python classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

# %% [markdown]
# ###### 1)Complete the below code to get the expected output.
#
# Sample Output:
#
# name=Raj salary=$20000
#
# ### Code ####
#
#
# class employee:
#
#         def __init__(self,name,salary):
#
#             self.name=name
#
#             self.salary=salary
#
#
#         def __str__(self):
#
#                 ###### write Your code
#
# e1=employee("Raj",20000)
#
# print(e1)

# %% [markdown]
# ###### 2) Complete the below code to get the expected output.
#
# Hint: The len() method invokes the __len__ magic method.
#
# It takes one positional argument and returns the length of the object.
#
# Expected Output:
#
# Executing __len__()
#
# 18
#
# ### Code ####
#
#
# class RectangleClass(object):
#
#     def __init__(self, area, breadth):
#
#         self._area = area
#
#         self._breadth = breadth
#
#     def __len__(self):
#
# 	##write your code here
#
# rc = RectangleClass(90, 5)
#
# print(len(rc))

# %% [markdown]
# ###### 3) Complete the below code to get the expected output.
#
# Expected Output:
#
# Total difference: -300
#
# ### Code ####
#
# class Difference():
#
#     def __init__(self, count):
#
#         self.count = count
#
#     def __sub__(self, other):
#
#         ###write your code
#
#     def __str__(self):
#
#                 ###write your code
#
# c1 = Difference(200)
#
# c2 = Difference(500)
#
# c3 = c1 - c2
#
# print(c3)

# %% [markdown]
# ###### 4)Complete the below code to get the following output.
#
# Sample Output:
#
# True
#
# False
#
# True
#
# True
#
# Hint:
#
# The __eq__ method executes when two objects are compared using == operator.
#
# The __ne__ method executes when two objects are compared using != operator.
#
# The __le__ method executes when two objects are compared using <= operator.
#
# The __ge__ method executes when two objects are compared using >= operator.
#
#
# ### Code ####
#
#
# class Area:
#
#     def __init__(self, height, width):
#
#         self.height = height
#
#         self.width = width
#
#     def __eq__(self, other):
#
# 	###write your code
#
#     def __ne__(self, other):
#
#         ###write your code
#
#     def __le__(self, other):
#
#         ###write your code
#
#     def __ge__(self, other):
#
#         ###write your code
#
# a1 = Area(7, 10)
#
# a2 = Area(35, 2)
#
# print(a1 == a2)
#
# print(a1 != a2)
#
# print(a1 <= a2)
#
# print(a1 >= a2)
