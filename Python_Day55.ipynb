# %% [markdown]
# # Important Instructions

# %% [markdown]
# ###### I hope you enjoyed Python classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Using the above uml diagram write a script to achieve polymorphism.
#
# Sample Output:
#
# Send Money Through PayPal
#
# Receive Money Through PayPal
#
# Paypal Contains mobile_card_reader
#
# Send Money Through AmazonPay
#
# Receive Money Through AmazonPay
#
# AmazonPay provides gift_cards
#
# Send Money Through PhonePay
#
# Receive Money Through PhonePay
#
# PhonePay provides pos_payments

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Using the above uml diagram write a script to achieve polymorphism
#
# Sample Output:
#
# Vertebrates eats
#
# Vertebrates sleep
#
# vertebrates are warm-blooded
#
# Vertebrates comes with backbone
#
# Invertebrates eat
#
# Invertebrates sleep
#
# Invertebrates are multicellular.
#
# Invertebrates comes without backbone
