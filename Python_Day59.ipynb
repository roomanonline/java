# %% [markdown]
# # Important Instructions

# %% [markdown]
# ###### I hope you enjoyed Python classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

# %% [markdown]
# 1) ![image.png](attachment:image.png)

# %% [markdown]
# ###### In, the above diagram ATM is abstract class withdraw_cash(),deposite_cash(),balance_enquiry() is abstract method ,write a script to achieve polymorphism and abstraction to get the following output.
#
# <b>Sample Output:</b>
#
# withdraw amount from sbi card
#
# deposite amount to sbi
#
# Balance enquiry using sbi card
#
# withdraw amount from icici_card
#
# deposite amount to icici
#
# Balance enquiry using icici card
#
# withdraw amount from kotak card
#
# deposite amount to kotak card
#
# Balance enquiry using kotak card

# %% [markdown]
# 2) ![image.png](attachment:image.png)

# %% [markdown]
# ###### In, the above diagram Microsoft_Office is abstract class open_app(),edit(),close_app()is abstract method ,write a script to achieve polymorphism and abstraction to get the following output.
#
# <b>Sample Output:</b>
#
# open MS_powerpoint
#
# Make Presentation using MS_powerpoint
#
# close MS_powerpoint
#
# open MS_word
#
# Make notes,documents using MS_word
#
# close MS_word
#
# open MS_Excel
#
# Make create grids of text, formulas specifying calculations using MS_Excel
#
# close MS_Excel
