# %% [markdown]
# # Important Instructions

# %% [markdown]
# ###### I hope you enjoyed Python classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Write a script for the above uml diagram to achieve has-a relationship and print the expected output.
#
# Sample Output:
#
# Person: Raj , 49
#
# Brain : Human brain weighs about 3 pounds!!!
#
# Bike: Ducati , 60lakh , red

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Write a script for the above uml diagram to achieve has-a relationship and print the expected output.
#
# Sample Output:
#
# Mobile: One+ , 49000 , Black
#
# Application: candy crush , 62 MB , 4.6
#
# Charger : VOZC , 900 , White
