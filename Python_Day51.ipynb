# %% [markdown]
# # Important Instructions

# %% [markdown]
# ###### I hope you enjoyed Python classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

# %% [markdown]
# ##### Write a script to achieve ENCAPSULATION for the following scenario.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Here is the Bank class where you can set the ATM pin based on the condition below.
#
# Length of the pin should be 4 and negative values are not allowed.
#
# If the pin is set then new pin should be displayed to user
#
# If pin is not set then current pin should be set as new pin.
#
# <b>Hint: current pin is by default 0000</b>
#
#
# <b>Sample Input 1 :</b>
#
# Current pin 0000
#
# Enter the new pin:-98
#
# <b>Sample Output 1:</b>
#
# Invalid Pin! Try again
#
# New Pin: 0000
#
#
# <b>Sample Input 2:</b>
#
# Current pin 0000
#
# Enter the new pin:6945
#
# <b>Sample Output 2:</b>
#
# New Pin: 6945
