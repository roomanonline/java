// %% [markdown]
// # Important Instructions:
// 1)When coding in java using jupyter notebooks there is no need to provide a main method as it is automatically provided.
//
// 2)Code written within a cell is automatically placed within the main method unless you explicitly place it within another class
//
// I hope you enjoyed the classes and have built a good foundation for the logic involved. Now lets solve a few intresting questions to see what kind of logic you can come up with :)

// %% [markdown]
// 1.	Create one superclass called Employee and two subclasses –  Contractor and FullTimeEmployee. Both subclasses have common properties to share, like the name of the employee and the amount of money the person will be paid per hour. There is one major difference between contractors and full-time employees – the time they work for the company. Full-time employees work constantly 8 hours per day and the working time of contractors may vary.
// Hint:
// Employee class constructor used accept name and paymentPerHour as parameters
// Contractor class constructor used accept name and paymentPerHour and workingHours as parameters since working hour of contractor varies
// ![pic.jpg](attachment:pic.jpg)

// %% [raw]
// 2.Create an abstract class 'Animals' with two abstract methods 'cats' and 'dogs'. Now create a class 'Cats' with a method 'cats' which prints "Cats meow" and a class 'Dogs' with a method 'dogs' which prints "Dogs bark", both inheriting the class 'Animals'. Now create an object for each of the subclasses and call their respective methods.
//
// Sample output :
// Dogs bark
// Cats meow

// %% [raw]
// 3.	Create an abstract class 'Bank' with an abstract method 'Rs.10000, Rs.80000 and Rs.200000 are deposited in banks A, B and C respectively. 'BankA', 'BankB' and 'BankC' are subclasses of class 'Bank', each having a method named 'getBalance'. Call this method by creating an object of each of the three classes.
//
// Sample output:
// Fetching balance from respective Banks :
//
// BankA : Rs.10000
// BankB : Rs.80000
// BankC : Rs.200000

// %% [markdown]
// 4. Write a program to illustrate Has-A relationship by referring below Class diagram:
//
// ![has-aPic.JPG](attachment:has-aPic.JPG)
//
// Sample output :
//
// Name : Varun
// Address : House No - 100 Locality - BNagar
// Name : Arun
// Address : House No - 135 Locality – Snagar

// %% [raw]
// 5. An abstract class has a construtor which prints "This is constructor of abstract class", an abstract method named 'a_method' and a non-abstract method which prints "This is a normal method of abstract class". A class 'SubClass' inherits the abstract class and has a method named 'a_method' which prints "This is abstract method". Now create an object of 'SubClass' and call the abstract method and the non-abstract method.
//
// Sample output:
// This is constructor of abstract class
// This is abstract method
// This is a normal method of abstract class

// %% [raw]
// 6. Consider two classes, Test class is trying to access the default method of Addition class, since class Test belongs to a different package, this program would throw compilation error, because the scope of default modifier is limited to the same package in which it is declared.
// package abcpackage;
//
// public class Addition {
//    /* Since we didn't mention any access modifier here, it would
//     * be considered as default.
//     */
//    int addTwoNumbers(int a, int b){
// 	return a+b;
//    }
// }
// package xyzpackage;
//
// import abcpackage.*;
//
// public class Test {
//    public static void main(String args[]){
// 	Addition obj = new Addition();
//         /* It will throw error because we are trying to access
//          * the default method in another package
//          */
// 	obj.addTwoNumbers(10, 21);
//    }
// }
//
// What changes should we make to solve the error ?

// %% [raw]
// 7.Create a new package called One.
//  Create a new class, Alpha in package one.
//  Declare below instance variables in Alpha class.
//      public int pub;
//      protected int prot;
//      int pack;
//      private int pri;
//
// create a new package called two and create a new Beta class.
// Try to use all variables of Alpha class in Beta class.
//
// Note : If you get error correct the code and Justify the same.

// %% [raw]
// 8. Write Employee class in which Number of Leaves is fixed and cannot be modified.
// Hint : final variable
//
// Sample output:
// Number of leaves : 12
